# %% [markdown]
# <a href="https://colab.research.google.com/github/torcodex/Python-Data-Structures/blob/main/DS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lists

# %%
a = [3,5,6,7]
print(type(a))
d = [3,5,6,7,"adsgf","3es"]
print(type(d))
# Out:
# <class 'list'>
# <class 'list'>

# %% [markdown]
# Tuple

# %%
b = (4,2,8,6)
print(type(b))
# Out:
# <class 'tuple'>

# %% [markdown]
# Set

# %%
c = <4,6,4,3,2,9>
print(type(c))

# %% [markdown]
# Pandas Data structures!

# %%
import pandas as pd
import numpy as np

# %%
std = {"A":[3,5,3,2,6,8,4],"B":[4,6,8,3,4,7,1]}
df = pd.DataFrame(data=std)
print(df)
# Out:
#    A  B
# 0  3  4
# 1  5  6
# 2  3  8
# 3  2  3
# 4  6  4
# 5  8  7
# 6  4  1
